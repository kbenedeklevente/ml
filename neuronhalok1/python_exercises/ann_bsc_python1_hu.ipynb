# %% [markdown]
# **Created by:**
#
# __Viktor Varga__
#
# <br>
# <img src="https://docs.google.com/uc?export=download&id=1q8cQBQKSLqS3PirWEmtQyObewgHOVISl" style="display:inline-block" width='40%'>
# <hr>

# %% [markdown]
# # Python tutorial - 1. fejezet

# %% [markdown]
# ## A Google Colaboratory használata

# %% [markdown]
# **Az általunk használt verzió: Python 3.6**
#
# **Google Colab beállítása a megfelelő verzióra:** Edit --> Notebook Settings --> Runtime type --> Python 3
#
# A Google Colab az .ipynb kiterjesztésű Jupyter notebookokat szerkeszti. Egy Jupyter notebook kódblokkokból és szöveges blokkokból áll. A kódblokkok egyenként is lefuttathatók, de az egész notebook is futtatható egyszerre.
#
# **Egyetlen blokk futtatása:** a blokk bal felső sarkában kattintásra megjelenő gomb segítségével lehetséges (illetve a blokkot kijelölve Ctrl+Enter segítségével is).
#
# **Az egész notebook futtatása:** a Runtime menü 'Run all' elemével indítható (vagy Ctrl+F9).
#
# Ha a blokk bármilyen kiírható/kirajzolható eredményt ad (explicit print függvény használat, vagy plottolás, illetve az utolsó önmagában álló kifejezés eredménye), az a blokk alatt fog megjelenni. Ha hiba történik egy blokk végrehajtása során, a hiba is kiíródik és ott megáll a notebook kiértékelése.
#
# A végrehajtást itt a notebookhoz automatikusan kapcsolt futtatókörnyezet biztosítja, aminek az állapota a jobb felső sarokban látható, pl. "Connected".
#
# A Google Docs-hoz hasonlóan, egy notebook megosztható **view only** és **can edit** jogosultságokkal is. Ha a notebook **view only** jogosultságokkal van megosztva valakivel, akkor az adott illető nem tudja szerkeszteni és futtatni sem a notebookot, csak a szöveges- és kód blokkokat látja, valamint az utolsó futtatás eredményét a kódblokkok alatt. A **view only** jogosultsággal rendelkezők természetesen lemásolhatják a notebook-ot a saját Drive-ukra és ott már szerkeszthetik, illetve futtathatják is azt (File --> Save a copy in Drive). Ezenkívül, egy **view only** notebook megnyitható **playground módban** is: ekkor egy átmeneti másolat készül a notebookról, ami szerkeszthető, azonban ha a notebookot nem mentjük el a saját Drive-unkra mielőtt kilépünk, a változtatásaink elvesznek.
#
# A notebook-ok letölthetőek és saját Jupyter futtatókörnyezettel is használhatók. Az .ipynb fájlok .html fájlokká konvertálhatók Jupyter segítségével, így offline, futtatókörnyezet nélkül is olvasgathatók.
#
# **Jupyter notebook lefuttatása**
#
# A Jupyter notebookok a Python interpreterhez hasonlóan működnek. A notebook futtatása után a notebook kód-blokkjaiban deklarált változók fennmaradnak, amíg a futtatókörnyezet csatlakoztatva van. Ha ezután esetleg újrafuttatunk egy (korábban már lefuttatott) blokkot, az eredménye már más lehet, mint akkor, amikor az egész notebookot először futtattuk. Gondoljunk csak arra, hogy egy blokkban deklarálunk és definiálunk egy változót kezdeti értékkel, majd a következő blokkban megnöveljük ezt az értéket: ha utóbbi kétszer fut le, a változó értéke más lesz, mintha egyszer futott volna le. A "Runtime" menü "Restart runtime" opciója **újraindítja a futtatókörnyezetet**, így elkerülhetjük a fent leírt problémát.
#
# **Google Colab futtatókörnyezet beállításai:**
#
# A Google videokártyát is biztosít ingyen a  notebookok gyorsításához. A videokártyás gyorsítás azonban csak az ezt kihasználó könyvtáraknál működik, mint például a Tensorflow, PyTorch. Egyszerű Python/Numpy kód futási idején ez a funkció nem változtat a Colab-ban. A videokártyás gyorsítás bekapcsolható: Edit --> Notebook Settings --> Hardware accelerator --> GPU.
#
# **Python cheat sheet:**
#
# https://perso.limsi.fr/pointal/_media/python:cours:mementopython3-english.pdf

# %% [markdown]
# ## Python szkriptek futtatása
#
# Bár az óra keretében csak az interpreter jellegű Google Colaboratory-t fogjuk használni, mégis, a legalapvetőbb módja a Python használatának a Python szkriptfájlok futtatása. A szkriptfájlok konvencionálisan a '.py' fájlkiterjesztést kapják. Futtatásukhoz saját (vagy távoli) gépre telepített Python környezet szükséges. Windows-on WinPython és Anaconda disztribúciók a leggyakoribbak, utóbbi ajánlott. Linuxon a Python 2.7 része a rendszernek tipikusan, de Python 3 telepítése a Linux disztribúció csomagkezelőjével történhet (Ubuntu-n pl. apt-get). Windows-on cmd, vagy az Anaconda parancssorából, Linuxon a bash-ből futtatható a szkript, pl. így:
#
# ```
# python3 szkript.py
# ```
#
# A szkript ekkor lefut, majd a Python futtatási környezet futása is befejeződik: ellentétben az interpreterrel (pl. Jupyter/Google Colab) a definiált változók nem maradnak meg.

# %% [markdown]
# ## Hello World

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## Alapok

# %%
# this is a comment

'''
A block comment.
'''

4+7
3+5  # result of the last standalone expression is printed
# Out:
# 8

# %% [markdown]
# ### Számok és változók
#
# **Változók Python-ban:**
# Python-ban a változók típusa nem kötött és explicit típus deklaráció sem szükséges. A változó mindig egy-egy objektum memóriacímét tárolja, a változó típusa az éppen mutatott objektum típusa tehát. Új objektum számára a szükséges memóriaterület automatikusan foglalódik le, nincs szükség explicit deklarációra és memóriafoglalásra.

# %%
print("An integer:", 2)     # printing a number
print("Adding two integers:", 2 + 3) # basic arithmetics
print("Multiplication:", 6 * 4)
print("(Float) division:", 2 / 3) # float division -> !! in Python 2.x int/int is an integer division !!
print("(Integer) division:", 2 // 3) # integer division
print("Modulo:", 20 % 3)  # modulo operator
print("Power:", 2 ** 10) # power function
# Out:
# An integer: 2
# Adding two integers: 5
# Multiplication: 24
# (Float) division: 0.6666666666666666
# (Integer) division: 0
# Modulo: 2
# Power: 1024

# %%
print("\nVariables: ")

b = 2        # assigning an integer to variable 'c'
c = 3
d = 3.0      # assigning a floating point number to variable 'b'

print("Adding an integer to another integer results in an integer: ", b + c)
print("Adding an integer to a floating point number (float) results in a float: ", b + d)

d = 2.6      # floating point numbers
f = 8.0
g = 9.
h = .2

k = d
print("k:", k)
k += c       # C style +=, *=, ... exist
print("k:", k)

print("\nDifferent numeric types:")
print(type(1))
print(type(1.2))
# Out:
# Variables:
# Adding an integer to another integer results in an integer:  5
# Adding an integer to a floating point number (float) results in a float:  5.0
# k: 2.6
# k: 5.6
#
# Different numeric types:
# <class 'int'>
# <class 'float'>

# %%
print("\nPython integer implementation is practically unlimited (bigint), no overflow happens:")

s = 1234567787978
print(s ** 10)
# Out:
# Python integer implementation is practically unlimited (bigint), no overflow happens:
# 8225255794295796740818218362946426741228583519689825498680760619934235117895021781482959057574344507118114927892361831424

# %% [markdown]
# ### Sztringek

# %%
# In Python strings can be specified in many ways,
#   but they all instantiate objects of the same str class

print("string 1") # double quoted string
print('string 2') # single quoted string, same as the two above

print('''
poem line#1
poem line#2
''')  # multiple lined string

print('''hey''' + "ho") # the usual string operations work, e.g. concatenation, more on them later

j = 'string are just "strings",'
h = " also strings are 'immutable'"
f = j + h # String concatenation
print(f)

print("\nMultiplication: ")
ff = j*2
print(ff)
# Out:
# string 1
# string 2
#
# poem line#1
# poem line#2
#
# heyho
# string are just "strings", also strings are 'immutable'
#
# Multiplication:
# string are just "strings",string are just "strings",

# %% [markdown]
# ### Logikai kifejezések

# %%
print("\nBoolean operators: ")
print("True and False:", True and False) # Python Booleans are True and False
print("True or False:", True or True) # or keyword
print("not False:", not False) # not keyword
print("The type of True: ", type(True), '\n')

print("Three is greater than two:", 3 > 2) # value inequality check
print("More complex expression:", 1 < 2 <= 3)
print("3 equals 3:", 3 == 3) # value equality check
print("3 does not equal 3:", 3 != 3, '\n') # value inequality check

string1 = 'this is the comparable string'
string2 = string1   # string2 and string1 variables refer to the same object from now
string3 = 'this is the comparable string'
print("String operator '==' compares contents: ", string1 == string2)
print("String operator '==' compares contents: ", string1 == string3)
print("Operator 'is' tells whether they are the same object: ", string1 is string2)
print("Operator 'is' tells whether they are the same object: ", string1 is string3)
# Out:
# Boolean operators:
# True and False: False
# True or False: True
# not False: True
# The type of True:  <class 'bool'>
#
# Three is greater than two: True
# More complex expression: True
# 3 equals 3: True
# 3 does not equal 3: False
#
# String operator '==' compares contents:  True
# String operator '==' compares contents:  True
# Operator 'is' tells whether they are the same object:  True
# Operator 'is' tells whether they are the same object:  False

# %% [markdown]
# ### `NoneType` típus

# %%
a = None
print(a)
print(a is None)  # the None literal is a singleton object
print(a is not None)  # the 'is not' expression is a single operator (negation of 'is')

print(type(None))
# Out:
# None
# True
# False
# <class 'NoneType'>

# %% [markdown]
# ## Listák
#
# A lista tetszőleges, akár kevert típusú objektumokat tartalmazhat.
#
# Dokumentáció: https://docs.python.org/3/tutorial/datastructures.html
#
# **Python lista típus jellemzői:**
#
# A Python lista a default Python implementációban (CPython) egy C-ben írt mutató (pointer) tömbként van megvalósítva. A mérete dinamikusan nő: ha a lista mérete eléri a lefoglalt memóriaterület méretét, akkor egy új, nagyobb memóriaterület kerül lefoglalásra és a régi mutatók átmásolásra kerülnek az új területre.
#
# Mivel a lista tömbként van megvalósítva, egy elem elérési ideje és felülírása O(1), azaz konstans idejű. A végéhez való hozzáadás (`append(), extend()`) és végéről való törlés (`pop(-1)`) is konstans idejű, nem számítva azt az esetet, ha betelik a lefoglalt memóriaterület. Közbenső, vagy első elem törlése és beszúrása viszont O(n) idejű, hiszen nem láncolt listáról van szó: a beszúrt, vagy törölt közbenső elem mögötti elemeket át kell mozgatni előrébb, vagy hátrább.

# %%
my_list = [1, "abc", None, False]
print("A simple list. Elements may have different types:", my_list)

empty_list = []
print("An empty list:", empty_list, '\n')

copied_list = list(my_list)
print("A copy of my_list:", copied_list)
print("Is copied_list the same object as my_list? ", copied_list is my_list)

jagged_list = [[2,3], ['r',[]], 'a', [None]]
print("Lists can contain any type of objects, other lists as well: ", jagged_list)
# Out:
# A simple list. Elements may have different types: [1, 'abc', None, False]
# An empty list: []
#
# A copy of my_list: [1, 'abc', None, False]
# Is copied_list the same object as my_list?  False
# Lists can contain any type of objects, other lists as well:  [[2, 3], ['r', []], 'a', [None]]

# %%
print("\nIndexing a list: ")
basic_list = [1,2,3,4,5]
print("A basic list:", basic_list)
print("Element at index 2 in the basic list (third element):", basic_list[2])
                                  # Indexing starts with ZERO and goes to length-1

print("2nd element counting from the back of the basic list:", basic_list[-2])
                                  # Negative index ''-k' corresponds to length-k

length = len(jagged_list) # this is a function returning an int, the length of the given list
print(length, 'is the length of the jagged list: ', jagged_list)
# Out:
# Indexing a list:
# A basic list: [1, 2, 3, 4, 5]
# Element at index 2 in the basic list (third element): 3
# 2nd element counting from the back of the basic list: 4
# 4 is the length of the jagged list:  [[2, 3], ['r', []], 'a', [None]]

# %%
print("\nMethods of the list class:")

basic_list.append(3)
print("Appended one element to the end: ", basic_list)

basic_list.append([3, 4])
print("Appended one element (a list with a length of two) to the end: ", basic_list)

basic_list.extend([3, 4])
print("Extended the list with two elements: ", basic_list)

basic_list.insert(0, None)
print("Inserted an element to the from of the list (index 0): ", basic_list)

basic_list.insert(-1, None)
print("Inserted an element to the back of the list (index -1): ", basic_list)
# Out:
# Methods of the list class:
# Appended one element to the end:  [1, 2, 3, 4, 5, 3]
# Appended one element (a list with a length of two) to the end:  [1, 2, 3, 4, 5, 3, [3, 4]]
# Extended the list with two elements:  [1, 2, 3, 4, 5, 3, [3, 4], 3, 4]
# Inserted an element to the from of the list (index 0):  [None, 1, 2, 3, 4, 5, 3, [3, 4], 3, 4]
# Inserted an element to the back of the list (index -1):  [None, 1, 2, 3, 4, 5, 3, [3, 4], 3, None, 4]

# %% [markdown]
# Other list methods:
#
# `pop(), remove(), clear(), sort(), ...`

# %%
print("\nSlice and stride: ")
# Format of list slicing: my_list[from:to:step]
#   iteration goes from 'from' (inclusive) to 'to' (exclusive) with a step size of 'step'
#   second colon (':') and any of 'from', 'to' or 'step' can be omitted

my_list = [0,1,2,3,4,5]
print("The original list: ", my_list)
print("From idx 2 to idx 4 (exclusive): ", my_list[2:4])
print("From idx 2 to idx 4 (exclusive) with step size 2: ", my_list[2:4:2])
print("From idx 2 to the end: ", my_list[2:])
print("From the beginning till idx 2 (exclusive): ", my_list[:2], '\n')

print("Whole list with step size 2: ", my_list[::2])
print("Reversed list: ", my_list[::-1])
print("Reversed list with step size 2: ", my_list[::-2])
print("Reversed list with step size 2, starting"\
            " from second but last element towards the beginning: ", my_list[-2::-2])

# when slicing the reversed list, the 'from' marks the latter index and
# 'to' is the smaller one, closer to the front as we iterate in the opposite direction
# Out:
# Slice and stride:
# The original list:  [0, 1, 2, 3, 4, 5]
# From idx 2 to idx 4 (exclusive):  [2, 3]
# From idx 2 to idx 4 (exclusive) with step size 2:  [2]
# From idx 2 to the end:  [2, 3, 4, 5]
# From the beginning till idx 2 (exclusive):  [0, 1]
#
# Whole list with step size 2:  [0, 2, 4]
# Reversed list:  [5, 4, 3, 2, 1, 0]
# Reversed list with step size 2:  [5, 3, 1]
# Reversed list with step size 2, starting from second but last element towards the beginning:  [4, 2, 0]

# %%
print("When slicing, out of range indices will not raise an error: ", my_list[:8])
print("When slicing, out of range indices will not raise an error: ", my_list[7:8])

# indexing with a single out of range index would of course cause an error

print("\nString is also a sequence type:")
s = 'abcdef'
print(s[2])
print(s[-1])
print(s[:4])
print(s[-2:1:-1])
# Out:
# When slicing, out of range indices will not raise an error:  [0, 1, 2, 3, 4, 5]
# When slicing, out of range indices will not raise an error:  []
#
# String is also a sequence type:
# c
# f
# abcd
# edc

# %% [markdown]
# ## Elágazások, ciklusok, `pass` kulcsszó
#
# A Python blokkok whitespace karakterek segítségével vannak jelölve: `for, while, if, else, elif` után indentált blokk kell, hogy következzen. Az indentálás a sor elején található whitespace karakterek számának növelését jelenti. Egy blokk összes utasításának ugyanannyi whitespace karakterrel kell kezdenie a sort. Whitespace karakter lehet tabulátor és szóköz is, de a kettő keverése nem lehetséges (a Google Colab szóközzel helyettesíti a tab-okat).

# %%
print("\nIf statements: ")
ch = 'a'
if ch == 'a':
  print(1)

if ch == 'b':
  print(2)
elif ch == 'c':
  print(3)

if ch == 'b':
  print(4)
else:
  print(5)

if ch == 'd':
  print(6)
elif ch == 'a':
  print(7)
else:
  print(8)
# Out:
# If statements:
# 1
# 5
# 7

# %%
print("\nFor loop with the range() built-in function: ")
for i in range(2,7,2): # simple ranged for iterating through the range object
    print('  ', i)

sum = 0
for k in range(20): # summation with for
    sum += k
print("\nSum is ", sum)

# range() is a built-in function which returns an iterator over integers
#   range(to) will iterate from 0 (inclusive) until 'to' (exclusive)
#   range(from, to) will iterate from 'from' (inclusive) until 'to' (exclusive)
#   range(from, to, step), similar as in list slicing

# Warning! In Python 2.x range() returned a list, not an iterator.

print("\nIterating over elements of a list: ")
my_list = ['hello', None, '22', 2]
for item in my_list:
    print('  ', item)
# Out:
# For loop with the range() built-in function:
#    2
#    4
#    6
#
# Sum is  190
#
# Iterating over elements of a list:
#    hello
#    None
#    22
#    2

# %%
print("\nWhile loop: ")
i = 0
while(i < 5):
    print('  ', i)
    i +=1

print('\nPass is the empty statement ')
for i in range(10):
    pass    # do nothing: empty indented block results in a syntax error
            #    this is why 'pass' exists
# Out:
# While loop:
#    0
#    1
#    2
#    3
#    4
#
# Pass is the empty statement
