# %% [markdown]
# # 3. szorgalmi házi feladat
#
# A 3. szorgalmi házi feladathoz előfeltétel a 3. kötelező házi feladat megoldása. Vizsgálandó, hogy milyen teljesítmény érhető el előtanított mélyhálók használatával a kötelező házi feladat két részén, finomhangolással.
#
# Érdemes megnézni először a Canvas-on a "3. szorgalmi házi feladat elérhető" bejegyzést útmutatásért.
#
# A részleteket lásd lentebb.
#
# **(Végső) határidő:**  2022. május 29., vasárnap, 23:59.
#
# **Pontozás:** A szorgalmi házi feladat helyes megoldása esetén 5 pont szerezhető. A szerzett extra pontok vizsgázást követően is beszámíthatók a tárgyra beírt végső jegybe.
#
# **!!! A feladatok megoldását, illetve a megoldások jelentős részét tartalmazó kódrészletet bárhol közzétenni tilos !!!**
#
# **Megoldás és beküldés menete:**
#
# A közzétett, feladatokat tartalmazó Google Colab notebook csak "view" jogosultságokkal van megosztva, így, bár a notebook szerkeszthetőnek látszik, az úgynevezett "Playground" módban nyílik meg, ahol a változtatások nem lesznek mentve. Mindenkinek le kell másolnia a saját Drive-jára a notebook-ot (Google Colab file menü -> Save a copy to Drive): a másolat már maradandóan szerkeszthető és futtatható lesz. **A kész megoldást tartalmazó notebook-ot le kell tölteni**  (Google Colab file menü -> Download .ipynb), **majd a Canvas-ban, a kiírt feladatnál feltölteni.** Link nem adható be, csak az .ipynb fájl. Alternatívaként, Google Colab helyett saját gépen futó Python-nal és Jupyter-rel is szerkeszthetők és futtathatók .ipynb notebookok.

# %% [markdown]
# ###**R**: Multi-class klasszifikáció előtanított mélyháló felhasználásával
#
# Módosítsd a kötelező házi feladat notebookját úgy, hogy az F és H részfeladatokban egy internetről letöltött, előtanított hálót finomhangolsz a klasszifikációs feladatra! Az előtanított hálót a `keras.applications` csomagból érdemes kiválasztani: a hozzá elérhető előtanított súlyokat le lehet tölteni.
#
# Több információ: https://keras.io/applications/ (A MobileNet v2 a legkisebb közülük és bőven megfelelő a célra)
#
# - Töltsd be és alakítsd át az előtanított hálót a célfeladatra (klasszifikáció 5 kategóriába)!
# - Finomhangold a hálót a célfeladaton!
# - Hasonlítsd össze a klasszifikációs accuracy-t a kötelező házi feladatban elért accuracy-val a teszthalmazon! Javasolt az összehasonlításhoz azonos seed-et rögzíteni a notebook elején, mint a kötelező házi feladat notebookjában, hogy ugyanaz legyen pontosan a tanító-/validációs- és teszthalmaz felbontás és a kiértékelés fair legyen.
# - Rajzolj/írj ki néhány predikciót az I feladatnak megfelelően!
# - Rajzolj ki tanítási és validációs görbéket!
# - Próbáld ki, milyen hatással van a betanításra, ha befagyasztod az előtanított háló súlyait!
# - Értékeld szövegesen, 2-3 mondatban az eredményt!

# %% [markdown]
# ###**S**: Bináris szegmentáció előtanított mélyháló felhasználásával
#
# Módosítsd a kötelező házi feladat notebookját úgy, hogy az N és P részfeladatokban egy internetről letöltött, előtanított hálót finomhangolsz a szegmentációs feladatra! Több, Keras kompatibilis, szegmentációs architektúrákat tartalmazó csomag érhető el, ajánlott például a `segmentation_models` csomagot használni. További részletekért és útmutatásért lásd a Canvas-on a "3. szorgalmi házi feladat elérhető" fórumbejegyzést.
#
# - Töltsd be az előtanított hálót és alakítsd át azt a megfelelő célfeladathoz (bináris szegmentáció)! (Ha a `segmentation_models` csomagot használod, az elvégzi az átalakításokat, ehhez mindössze néhány extra paramétert kell megadnod a modell példányosításánál. A `segmentation_models` csomagban található architektúrák esetén az input és az output ugyanakkora. Azaz, vagy át kell alakítanod a hálót, hogy leskálázza az output-ot, vagy elhagyni teljesen az output leskálázását és meghagyni az eredeti 128x128-as felbontását.)
# - Finomhangold a hálót a célfeladaton!
# - Hasonlítsd össze a MAE metrikát a kötelező házi feladatban elért MAE-val a teszthalmazon! Javasolt az összehasonlításhoz azonos seed-et rögzíteni a notebook elején, mint a kötelező házi feladat notebookjában, hogy ugyanaz legyen pontosan a tanító-/validációs- és teszthalmaz felbontás és a kiértékelés fair legyen.
# - Rajzolj ki néhány maszk predikciót a képekkel együtt a Q feladatnak megfelelően!
# - Rajzolj ki tanítási és validációs görbéket!
# - Próbáld ki, milyen hatással van a betanításra, ha befagyasztod az előtanított háló rétegeit!
# - Értékeld szövegesen, 2-3 mondatban az eredményt!
